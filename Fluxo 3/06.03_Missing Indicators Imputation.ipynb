# %% [markdown]
# ## This notebook inputs the missing values using Missing Indicators

# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.impute import MissingIndicator

# %% [markdown]
# #### Choose wether the imputation should be done on the data set with daily or weekly granularity

# %%
#INPUT, OUTPUT = 'CompleteIndexes.csv','MIImputed.csv'
INPUT, OUTPUT = 'CompleteWeeklyIndexes', 'MIIWeeklyImputed'

# %%
df = pd.read_csv(INPUT+'_training_FE.csv', parse_dates=True, index_col=0)
df_test = pd.read_csv(INPUT+'_test_FE.csv', parse_dates=True, index_col=0)

# %%
indicator = MissingIndicator(missing_values=np.nan, features="all")

# %%
indicator.fit(df)
mask_all = indicator.transform(df)
mask_test_all = indicator.transform(df_test)

# %%
df_masks = pd.DataFrame(data=mask_all, index=df.index, columns=df.columns)
df_test_masks = pd.DataFrame(data=mask_test_all, index=df_test.index, columns=df_test.columns)

# %%
df_masks = df_masks.add_prefix('MI_')
df_test_masks = df_test_masks.add_prefix('MI_')

# %%
df_final = pd.concat([df, df_masks], axis=1, join='outer')
df_test_final = pd.concat([df_test, df_test_masks], axis=1, join='outer')

# %%
df_final.head()
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume     dji_Close  \
# 2000-01-07  1441.469971  1.225200e+09  21.719999         0.0  11522.559570
# 2000-01-14  1465.150024  1.085900e+09  19.660000         0.0  11722.980469
# 2000-01-21  1441.359985  1.209800e+09  20.820000         0.0  11251.709961
# 2000-01-28  1360.160034  1.095800e+09  26.139999         0.0  10738.870117
# 2000-02-04  1424.369995  1.045100e+09  21.540001         0.0  10963.799805
#
#              dji_Volume    ndx_Close    ndx_Volume    n255_Close  n255_Volume  \
# 2000-01-07  184900000.0  3529.600098  1.634930e+09  18193.410156          0.0
# 2000-01-14  266830000.0  3704.739990  1.656630e+09  18956.550781          0.0
# 2000-01-21  205840000.0  3849.959961  1.923680e+09  18878.089844          0.0
# 2000-01-28  183090000.0  3446.129883  1.616370e+09  19434.779297          0.0
# 2000-02-04  166590000.0  3874.370117  1.751450e+09  19763.130859          0.0
#
#             ...  MI_vix_ROC2_13_52  MI_vix_ROC2_13_52_diff1_period3  \
# 2000-01-07  ...               True                             True
# 2000-01-14  ...               True                             True
# 2000-01-21  ...               True                             True
# 2000-01-28  ...               True                             True
# 2000-02-04  ...               True                             True
#
#             MI_vix_ROC2_5_26  MI_vix_ROC2_5_26_diff1_period3  \
# 2000-01-07              True                            True
# 2000-01-14              True                            True
# 2000-01-21              True                            True
# 2000-01-28              True                            True
# 2000-02-04              True                            True
#
#             MI_vix_ROC2_13_26  MI_vix_ROC2_13_26_diff1_period3  \
# 2000-01-07               True                             True
# 2000-01-14               True                             True
# 2000-01-21               True                             True
# 2000-01-28               True                             True
# 2000-02-04               True                             True
#
#             MI_vix_52_Week_High  MI_vix_52_Week_High_diff1_period3  \
# 2000-01-07                False                               True
# 2000-01-14                False                               True
# 2000-01-21                False                               True
# 2000-01-28                False                              False
# 2000-02-04                False                              False
#
#             MI_vix_52_Week_Low  MI_vix_52_Week_Low_diff1_period3
# 2000-01-07               False                              True
# 2000-01-14               False                              True
# 2000-01-21               False                              True
# 2000-01-28               False                             False
# 2000-02-04               False                             False
#
# [5 rows x 824 columns]

# %%
df.head()
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume     dji_Close  \
# 2000-01-07  1441.469971  1.225200e+09  21.719999         0.0  11522.559570
# 2000-01-14  1465.150024  1.085900e+09  19.660000         0.0  11722.980469
# 2000-01-21  1441.359985  1.209800e+09  20.820000         0.0  11251.709961
# 2000-01-28  1360.160034  1.095800e+09  26.139999         0.0  10738.870117
# 2000-02-04  1424.369995  1.045100e+09  21.540001         0.0  10963.799805
#
#              dji_Volume    ndx_Close    ndx_Volume    n255_Close  n255_Volume  \
# 2000-01-07  184900000.0  3529.600098  1.634930e+09  18193.410156          0.0
# 2000-01-14  266830000.0  3704.739990  1.656630e+09  18956.550781          0.0
# 2000-01-21  205840000.0  3849.959961  1.923680e+09  18878.089844          0.0
# 2000-01-28  183090000.0  3446.129883  1.616370e+09  19434.779297          0.0
# 2000-02-04  166590000.0  3874.370117  1.751450e+09  19763.130859          0.0
#
#             ...  vix_ROC2_13_52  vix_ROC2_13_52_diff1_period3  vix_ROC2_5_26  \
# 2000-01-07  ...             NaN                           NaN            NaN
# 2000-01-14  ...             NaN                           NaN            NaN
# 2000-01-21  ...             NaN                           NaN            NaN
# 2000-01-28  ...             NaN                           NaN            NaN
# 2000-02-04  ...             NaN                           NaN            NaN
#
#             vix_ROC2_5_26_diff1_period3  vix_ROC2_13_26  \
# 2000-01-07                          NaN             NaN
# 2000-01-14                          NaN             NaN
# 2000-01-21                          NaN             NaN
# 2000-01-28                          NaN             NaN
# 2000-02-04                          NaN             NaN
#
#             vix_ROC2_13_26_diff1_period3  vix_52_Week_High  \
# 2000-01-07                           NaN          0.000000
# 2000-01-14                           NaN         -0.099647
# 2000-01-21                           NaN         -0.042319
# 2000-01-28                           NaN          0.000000
# 2000-02-04                           NaN         -0.193555
#
#             vix_52_Week_High_diff1_period3  vix_52_Week_Low  \
# 2000-01-07                             NaN         0.000000
# 2000-01-14                             NaN         0.000000
# 2000-01-21                             NaN         0.057328
# 2000-01-28                        0.000000         0.284881
# 2000-02-04                       -0.093908         0.091326
#
#             vix_52_Week_Low_diff1_period3
# 2000-01-07                            NaN
# 2000-01-14                            NaN
# 2000-01-21                            NaN
# 2000-01-28                       0.284881
# 2000-02-04                       0.091326
#
# [5 rows x 412 columns]

# %%
df_final=df_final.fillna(0)
df_test_final=df_test_final.fillna(0)
df_final.head()
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume     dji_Close  \
# 2000-01-07  1441.469971  1.225200e+09  21.719999         0.0  11522.559570
# 2000-01-14  1465.150024  1.085900e+09  19.660000         0.0  11722.980469
# 2000-01-21  1441.359985  1.209800e+09  20.820000         0.0  11251.709961
# 2000-01-28  1360.160034  1.095800e+09  26.139999         0.0  10738.870117
# 2000-02-04  1424.369995  1.045100e+09  21.540001         0.0  10963.799805
#
#              dji_Volume    ndx_Close    ndx_Volume    n255_Close  n255_Volume  \
# 2000-01-07  184900000.0  3529.600098  1.634930e+09  18193.410156          0.0
# 2000-01-14  266830000.0  3704.739990  1.656630e+09  18956.550781          0.0
# 2000-01-21  205840000.0  3849.959961  1.923680e+09  18878.089844          0.0
# 2000-01-28  183090000.0  3446.129883  1.616370e+09  19434.779297          0.0
# 2000-02-04  166590000.0  3874.370117  1.751450e+09  19763.130859          0.0
#
#             ...  MI_vix_ROC2_13_52  MI_vix_ROC2_13_52_diff1_period3  \
# 2000-01-07  ...               True                             True
# 2000-01-14  ...               True                             True
# 2000-01-21  ...               True                             True
# 2000-01-28  ...               True                             True
# 2000-02-04  ...               True                             True
#
#             MI_vix_ROC2_5_26  MI_vix_ROC2_5_26_diff1_period3  \
# 2000-01-07              True                            True
# 2000-01-14              True                            True
# 2000-01-21              True                            True
# 2000-01-28              True                            True
# 2000-02-04              True                            True
#
#             MI_vix_ROC2_13_26  MI_vix_ROC2_13_26_diff1_period3  \
# 2000-01-07               True                             True
# 2000-01-14               True                             True
# 2000-01-21               True                             True
# 2000-01-28               True                             True
# 2000-02-04               True                             True
#
#             MI_vix_52_Week_High  MI_vix_52_Week_High_diff1_period3  \
# 2000-01-07                False                               True
# 2000-01-14                False                               True
# 2000-01-21                False                               True
# 2000-01-28                False                              False
# 2000-02-04                False                              False
#
#             MI_vix_52_Week_Low  MI_vix_52_Week_Low_diff1_period3
# 2000-01-07               False                              True
# 2000-01-14               False                              True
# 2000-01-21               False                              True
# 2000-01-28               False                             False
# 2000-02-04               False                             False
#
# [5 rows x 824 columns]

# %%
df_final.to_csv(OUTPUT+'_training_FE.csv', index = True)
df_test_final.to_csv(OUTPUT+ '_test_FE.csv', index = True)
