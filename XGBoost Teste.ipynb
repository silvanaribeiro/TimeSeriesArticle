# %%
import numpy as np

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import xgboost as xgb

# %%
cancer = load_breast_cancer()

X = cancer.data
y = cancer.target

xgb_model = xgb.XGBClassifier(objective="binary:logistic", n_estimators=200, random_state=42, eval_metric=["error"])

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

xgb_model.fit(X_train, y_train, eval_set=[(X_test, y_test)])

y_pred = xgb_model.predict(X_test)
print("______________________________")
print(confusion_matrix(y_test, y_pred))
# Out:
# [0]	validation_0-error:0.04895
# [1]	validation_0-error:0.04895
# [2]	validation_0-error:0.04196
# [3]	validation_0-error:0.04196
# [4]	validation_0-error:0.03497
# [5]	validation_0-error:0.04196
# [6]	validation_0-error:0.03497
# [7]	validation_0-error:0.04895
# [8]	validation_0-error:0.04895
# [9]	validation_0-error:0.04895
# [10]	validation_0-error:0.04895
# [11]	validation_0-error:0.04196
# [12]	validation_0-error:0.03497
# [13]	validation_0-error:0.04196
# [14]	validation_0-error:0.04196
# [15]	validation_0-error:0.04196
# [16]	validation_0-error:0.04196
# [17]	validation_0-error:0.04196
# [18]	validation_0-error:0.04196
# [19]	validation_0-error:0.04196
# [20]	validation_0-error:0.04196
# [21]	validation_0-error:0.04196
# [22]	validation_0-error:0.04196
# [23]	validation_0-error:0.04196
# [24]	validation_0-error:0.04196
# [25]	validation_0-error:0.04196
# [26]	validation_0-error:0.04196
# [27]	validation_0-error:0.04196
# [28]	validation_0-error:0.04196
# [29]	validation_0-error:0.04196
# [30]	validation_0-error:0.04196
# [31]	validation_0-error:0.03497
# [32]	validation_0-error:0.03497
# [33]	validation_0-error:0.03497
# [34]	validation_0-error:0.03497
# [35]	validation_0-error:0.03497
# [36]	validation_0-error:0.03497
# [37]	validation_0-error:0.03497
# [38]	validation_0-error:0.04196
# [39]	validation_0-error:0.04196
# [40]	validation_0-error:0.04196
# [41]	validation_0-error:0.04196
# [42]	validation_0-error:0.04196
# [43]	validation_0-error:0.04196
# [44]	validation_0-error:0.04196
# [45]	validation_0-error:0.03497
# [46]	validation_0-error:0.04196
# [47]	validation_0-error:0.03497
# [48]	validation_0-error:0.04196
# [49]	validation_0-error:0.04196
# [50]	validation_0-error:0.04196
# [51]	validation_0-error:0.03497
# [52]	validation_0-error:0.03497
# [53]	validation_0-error:0.03497
# [54]	validation_0-error:0.03497
# [55]	validation_0-error:0.03497
# [56]	validation_0-error:0.03497
# [57]	validation_0-error:0.03497
# [58]	validation_0-error:0.03497
# [59]	validation_0-error:0.03497
# [60]	validation_0-error:0.03497
# [61]	validation_0-error:0.03497
# [62]	validation_0-error:0.03497
# [63]	validation_0-error:0.03497
# [64]	validation_0-error:0.03497
# [65]	validation_0-error:0.03497
# [66]	validation_0-error:0.03497
# [67]	validation_0-error:0.03497
# [68]	validation_0-error:0.03497
# [69]	validation_0-error:0.03497
# [70]	validation_0-error:0.03497
# [71]	validation_0-error:0.03497
# [72]	validation_0-error:0.03497
# [73]	validation_0-error:0.03497
# [74]	validation_0-error:0.03497
# [75]	validation_0-error:0.03497
# [76]	validation_0-error:0.03497
# [77]	validation_0-error:0.03497
# [78]	validation_0-error:0.03497
# [79]	validation_0-error:0.03497
# [80]	validation_0-error:0.03497
# [81]	validation_0-error:0.03497
# [82]	validation_0-error:0.03497
# [83]	validation_0-error:0.03497
# [84]	validation_0-error:0.03497
# [85]	validation_0-error:0.03497
# [86]	validation_0-error:0.03497
# [87]	validation_0-error:0.03497
# [88]	validation_0-error:0.03497
# [89]	validation_0-error:0.03497
# [90]	validation_0-error:0.03497
# [91]	validation_0-error:0.03497
# [92]	validation_0-error:0.03497
# [93]	validation_0-error:0.03497
# [94]	validation_0-error:0.03497
# [95]	validation_0-error:0.03497
# [96]	validation_0-error:0.03497
# [97]	validation_0-error:0.03497
# [98]	validation_0-error:0.03497
# [99]	validation_0-error:0.03497
# [100]	validation_0-error:0.03497
# [101]	validation_0-error:0.03497
# [102]	validation_0-error:0.03497
# [103]	validation_0-error:0.03497
# [104]	validation_0-error:0.03497
# [105]	validation_0-error:0.03497
# [106]	validation_0-error:0.03497
# [107]	validation_0-error:0.03497
# [108]	validation_0-error:0.03497
# [109]	validation_0-error:0.03497
# [110]	validation_0-error:0.03497
# [111]	validation_0-error:0.03497
# [112]	validation_0-error:0.03497
# [113]	validation_0-error:0.03497
# [114]	validation_0-error:0.03497
# [115]	validation_0-error:0.02797
# [116]	validation_0-error:0.02797
# [117]	validation_0-error:0.02797
# [118]	validation_0-error:0.02797
# [119]	validation_0-error:0.02797
# [120]	validation_0-error:0.02797
# [121]	validation_0-error:0.02797
# [122]	validation_0-error:0.02797
# [123]	validation_0-error:0.02797
# [124]	validation_0-error:0.02797
# [125]	validation_0-error:0.02797
# [126]	validation_0-error:0.02797
# [127]	validation_0-error:0.02797
# [128]	validation_0-error:0.02797
# [129]	validation_0-error:0.02797
# [130]	validation_0-error:0.02797
# [131]	validation_0-error:0.02797
# [132]	validation_0-error:0.02797
# [133]	validation_0-error:0.02797
# [134]	validation_0-error:0.02797
# [135]	validation_0-error:0.02797
# [136]	validation_0-error:0.02797
# [137]	validation_0-error:0.02797
# [138]	validation_0-error:0.02797
# [139]	validation_0-error:0.02797
# [140]	validation_0-error:0.02797
# [141]	validation_0-error:0.02797
# [142]	validation_0-error:0.02797
# [143]	validation_0-error:0.02797
# [144]	validation_0-error:0.02797
# [145]	validation_0-error:0.02797
# [146]	validation_0-error:0.02797
# [147]	validation_0-error:0.02797
# [148]	validation_0-error:0.02797
# [149]	validation_0-error:0.02797
# [150]	validation_0-error:0.02797
# [151]	validation_0-error:0.02797
# [152]	validation_0-error:0.02797
# [153]	validation_0-error:0.02797
# [154]	validation_0-error:0.02797
# [155]	validation_0-error:0.02797
# [156]	validation_0-error:0.02797
# [157]	validation_0-error:0.02797
# [158]	validation_0-error:0.02797
# [159]	validation_0-error:0.02797
# [160]	validation_0-error:0.02797
# [161]	validation_0-error:0.02797
# [162]	validation_0-error:0.02797
# [163]	validation_0-error:0.02797
# [164]	validation_0-error:0.02797
# [165]	validation_0-error:0.02797
# [166]	validation_0-error:0.02797
# [167]	validation_0-error:0.02797
# [168]	validation_0-error:0.02797
# [169]	validation_0-error:0.02797
# [170]	validation_0-error:0.02797
# [171]	validation_0-error:0.02797
# [172]	validation_0-error:0.02797
# [173]	validation_0-error:0.02797
# [174]	validation_0-error:0.02797
# [175]	validation_0-error:0.02797
# [176]	validation_0-error:0.02797
# [177]	validation_0-error:0.02797
# [178]	validation_0-error:0.02797
# [179]	validation_0-error:0.02797
# [180]	validation_0-error:0.02797
# [181]	validation_0-error:0.02797
# [182]	validation_0-error:0.02797
# [183]	validation_0-error:0.02797
# [184]	validation_0-error:0.02797
# [185]	validation_0-error:0.02797
# [186]	validation_0-error:0.02797
# [187]	validation_0-error:0.02797
# [188]	validation_0-error:0.02797
# [189]	validation_0-error:0.02797
# [190]	validation_0-error:0.02797
# [191]	validation_0-error:0.02797
# [192]	validation_0-error:0.02797
# [193]	validation_0-error:0.02797
# [194]	validation_0-error:0.02797
# [195]	validation_0-error:0.02797
# [196]	validation_0-error:0.02797
# [197]	validation_0-error:0.02797
# [198]	validation_0-error:0.02797
# [199]	validation_0-error:0.02797
# ______________________________
# [[51  3]
#  [ 1 88]]
