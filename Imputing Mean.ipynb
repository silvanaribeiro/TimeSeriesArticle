# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('CompleteIndexes.csv', parse_dates=True, index_col=0)
df.head()
# Out:
#              sp500_Open   sp500_High    sp500_Low  sp500_Close  sp500_Volume  \
# 2000-01-01          NaN          NaN          NaN          NaN           NaN
# 2000-01-02          NaN          NaN          NaN          NaN           NaN
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  9.318000e+08
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1.009000e+09
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1.085500e+09
#
#              vix_Open  vix_High    vix_Low  vix_Close  vix_Volume  ...  \
# 2000-01-01        NaN       NaN        NaN        NaN         NaN  ...
# 2000-01-02        NaN       NaN        NaN        NaN         NaN  ...
# 2000-01-03  24.360001     26.15  23.980000  24.209999         0.0  ...
# 2000-01-04  24.940001     27.18  24.799999  27.010000         0.0  ...
# 2000-01-05  27.980000     29.00  25.850000  26.410000         0.0  ...
#
#              n100_High    n100_Low  n100_Close  n100_Volume  \
# ...

# %%
df.tail()
# Out:
#              sp500_Open   sp500_High    sp500_Low  sp500_Close  sp500_Volume  \
# 2020-03-14          NaN          NaN          NaN          NaN           NaN
# 2020-03-15          NaN          NaN          NaN          NaN           NaN
# 2020-03-16  2508.590088  2562.979980  2380.939941  2386.129883  7.781540e+09
# 2020-03-17  2425.659912  2553.929932  2367.040039  2529.189941  8.358500e+09
# 2020-03-18  2436.500000  2453.570068  2280.520020  2398.100098  8.755780e+09
#
#              vix_Open   vix_High    vix_Low  vix_Close  vix_Volume  ...  \
# 2020-03-14        NaN        NaN        NaN        NaN         NaN  ...
# 2020-03-15        NaN        NaN        NaN        NaN         NaN  ...
# 2020-03-16  57.830002  83.559998  57.830002  82.690002         0.0  ...
# 2020-03-17  82.690002  84.830002  70.370003  75.910004         0.0  ...
# 2020-03-18  69.370003  85.470001  69.370003  76.449997         0.0  ...
#
#              n100_High    n100_Low  n100_Close  n100_Volume  \
# ...

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(df)
# Out:
# SimpleImputer()

# %%
df_imputed = imp.transform(df)

# %%
df_final = pd.DataFrame(data=df_imputed, index=df.index, columns=df.columns)

# %%
print(df_imputed)
# Out:
# [[1.59134529e+03 1.60039188e+03 1.58144293e+03 ... 9.99779970e+01
#   1.37534283e+02 3.82231634e-02]
#  [1.59134529e+03 1.60039188e+03 1.58144293e+03 ... 9.99779970e+01
#   1.37534283e+02 3.82231634e-02]
#  [1.46925000e+03 1.47800000e+03 1.43835999e+03 ... 9.99779970e+01
#   1.37534283e+02 3.82231634e-02]
#  ...
#  [2.50859009e+03 2.56297998e+03 2.38093994e+03 ... 9.99779970e+01
#   1.37534283e+02 3.82231634e-02]
#  [2.42565991e+03 2.55392993e+03 2.36704004e+03 ... 9.99779970e+01
#   1.37534283e+02 3.82231634e-02]
#  [2.43650000e+03 2.45357007e+03 2.28052002e+03 ... 9.99779970e+01
#   1.37534283e+02 3.82231634e-02]]

# %%
df_final.head()
# Out:
#              sp500_Open   sp500_High    sp500_Low  sp500_Close  sp500_Volume  \
# 2000-01-01  1591.345295  1600.391879  1581.442932  1591.478805  3.109940e+09
# 2000-01-02  1591.345295  1600.391879  1581.442932  1591.478805  3.109940e+09
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  9.318000e+08
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1.009000e+09
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1.085500e+09
#
#              vix_Open   vix_High    vix_Low  vix_Close  vix_Volume  ...  \
# 2000-01-01  19.668822  20.502492  18.831182  19.554943         0.0  ...
# 2000-01-02  19.668822  20.502492  18.831182  19.554943         0.0  ...
# 2000-01-03  24.360001  26.150000  23.980000  24.209999         0.0  ...
# 2000-01-04  24.940001  27.180000  24.799999  27.010000         0.0  ...
# 2000-01-05  27.980000  29.000000  25.850000  26.410000         0.0  ...
#
#              n100_High    n100_Low  n100_Close   n100_Volume  \
# ...

# %%
df_final.to_csv(r'MeanImputed.csv', index = True)
