# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.impute import KNNImputer

# %%
df = pd.read_csv('CompleteIndexes.csv', parse_dates=True, index_col=0)
df.head()
# Out:
#              sp500_Open   sp500_High    sp500_Low  sp500_Close  sp500_Volume  \
# 2000-01-01          NaN          NaN          NaN          NaN           NaN
# 2000-01-02          NaN          NaN          NaN          NaN           NaN
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  9.318000e+08
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1.009000e+09
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1.085500e+09
#
#              vix_Open  vix_High    vix_Low  vix_Close  vix_Volume  \
# 2000-01-01        NaN       NaN        NaN        NaN         NaN
# 2000-01-02        NaN       NaN        NaN        NaN         NaN
# 2000-01-03  24.360001     26.15  23.980000  24.209999         0.0
# 2000-01-04  24.940001     27.18  24.799999  27.010000         0.0
# 2000-01-05  27.980000     29.00  25.850000  26.410000         0.0
#
#                          ...                  n100_High    n100_Low  \
# 2000-01-01               ...                        NaN         NaN
# 2000-01-02               ...                        NaN         NaN
# 2000-01-03               ...                 996.770020  996.770020
# 2000-01-04               ...                 955.969971  955.969971
# 2000-01-05               ...                 930.260010  930.260010
#
#             n100_Close  n100_Volume  Overall EMV Tracker  \
# 2000-01-01         NaN          NaN                  NaN
# 2000-01-02         NaN          NaN                  NaN
# 2000-01-03  996.770020          0.0                  NaN
# 2000-01-04  955.969971          0.0                  NaN
# 2000-01-05  930.260010          0.0                  NaN
#
#             infectious_daily_infect_emv_index        GPR  \
# 2000-01-01                               1.05  40.634806
# 2000-01-02                               2.62        NaN
# 2000-01-03                               0.00        NaN
# 2000-01-04                               0.99        NaN
# 2000-01-05                               0.00        NaN
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-01                                NaN
# 2000-01-02                                NaN
# 2000-01-03                                NaN
# 2000-01-04                                NaN
# 2000-01-05                                NaN
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-01                                      NaN
# 2000-01-02                                      NaN
# 2000-01-03                                      NaN
# 2000-01-04                                      NaN
# 2000-01-05                                      NaN
#
#             trade_Trade Policy EMV Fraction
# 2000-01-01                              NaN
# 2000-01-02                              NaN
# 2000-01-03                              NaN
# 2000-01-04                              NaN
# 2000-01-05                              NaN
#
# [5 rows x 46 columns]

# %%
imp = KNNImputer(n_neighbors=5, weights="uniform")

# %%
df_imputed = imp.fit_transform(df)

# %%
df_final = pd.DataFrame(data=df_imputed, index=df.index, columns=df.columns)

# %%
df_final.head()
# Out:
#              sp500_Open   sp500_High    sp500_Low  sp500_Close  sp500_Volume  \
# 2000-01-01  1591.126666  1600.396220  1582.222170  1590.939101  3.098755e+09
# 2000-01-02  1591.658233  1600.823078  1581.628693  1591.653180  3.098749e+09
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  9.318000e+08
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1.009000e+09
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1.085500e+09
#
#              vix_Open   vix_High    vix_Low  vix_Close  vix_Volume  \
# 2000-01-01  19.863569  20.556510  18.968284  19.746665         0.0
# 2000-01-02  19.652504  20.525862  18.856361  19.632749         0.0
# 2000-01-03  24.360001  26.150000  23.980000  24.209999         0.0
# 2000-01-04  24.940001  27.180000  24.799999  27.010000         0.0
# 2000-01-05  27.980000  29.000000  25.850000  26.410000         0.0
#
#                          ...                  n100_High    n100_Low  \
# 2000-01-01               ...                 813.153481  801.707389
# 2000-01-02               ...                 813.413133  803.754779
# 2000-01-03               ...                 996.770020  996.770020
# 2000-01-04               ...                 955.969971  955.969971
# 2000-01-05               ...                 930.260010  930.260010
#
#             n100_Close   n100_Volume  Overall EMV Tracker  \
# 2000-01-01  809.166719  1.921613e+08            19.879802
# 2000-01-02  808.639357  1.921606e+08            20.292464
# 2000-01-03  996.770020  0.000000e+00            13.550708
# 2000-01-04  955.969971  0.000000e+00            22.990910
# 2000-01-05  930.260010  0.000000e+00            23.953397
#
#             infectious_daily_infect_emv_index         GPR  \
# 2000-01-01                               1.05   40.634806
# 2000-01-02                               2.62  106.709597
# 2000-01-03                               0.00   73.362502
# 2000-01-04                               0.99   85.935791
# 2000-01-05                               0.00   19.373471
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-01                         106.257737
# 2000-01-02                         110.774959
# 2000-01-03                          73.056707
# 2000-01-04                         -37.747785
# 2000-01-05                        -112.931349
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-01                               138.351540
# 2000-01-02                               150.377793
# 2000-01-03                                90.235260
# 2000-01-04                                74.739891
# 2000-01-05                               -38.568472
#
#             trade_Trade Policy EMV Fraction
# 2000-01-01                         0.059137
# 2000-01-02                         0.042635
# 2000-01-03                         0.022696
# 2000-01-04                         0.013065
# 2000-01-05                         0.045240
#
# [5 rows x 46 columns]

# %%
df.to_csv(r'KNNImputed.csv', index = True)
