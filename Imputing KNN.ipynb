# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.impute import KNNImputer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-43d3cd0a0e70> in <module>
#       2 from datetime import datetime
#       3 import numpy as np
# ----> 4 from sklearn.impute import KNNImputer
#
# ImportError: cannot import name 'KNNImputer'

# %%
df = pd.read_csv('CompleteIndexes.csv', parse_dates=True, index_col=0)
df.head()
# Out:
#              sp500_Open   sp500_High    sp500_Low  sp500_Close  sp500_Volume  \
# 2000-01-01          NaN          NaN          NaN          NaN           NaN
# 2000-01-02          NaN          NaN          NaN          NaN           NaN
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  9.318000e+08
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1.009000e+09
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1.085500e+09
#
#              vix_Open  vix_High    vix_Low  vix_Close  vix_Volume  \
# 2000-01-01        NaN       NaN        NaN        NaN         NaN
# 2000-01-02        NaN       NaN        NaN        NaN         NaN
# 2000-01-03  24.360001     26.15  23.980000  24.209999         0.0
# 2000-01-04  24.940001     27.18  24.799999  27.010000         0.0
# 2000-01-05  27.980000     29.00  25.850000  26.410000         0.0
#
#                          ...                  n100_High    n100_Low  \
# 2000-01-01               ...                        NaN         NaN
# 2000-01-02               ...                        NaN         NaN
# 2000-01-03               ...                 996.770020  996.770020
# 2000-01-04               ...                 955.969971  955.969971
# 2000-01-05               ...                 930.260010  930.260010
#
#             n100_Close  n100_Volume  Overall EMV Tracker  \
# 2000-01-01         NaN          NaN                  NaN
# 2000-01-02         NaN          NaN                  NaN
# 2000-01-03  996.770020          0.0                  NaN
# 2000-01-04  955.969971          0.0                  NaN
# 2000-01-05  930.260010          0.0                  NaN
#
#             infectious_daily_infect_emv_index        GPR  \
# 2000-01-01                               1.05  40.634806
# 2000-01-02                               2.62        NaN
# 2000-01-03                               0.00        NaN
# 2000-01-04                               0.99        NaN
# 2000-01-05                               0.00        NaN
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-01                                NaN
# 2000-01-02                                NaN
# 2000-01-03                                NaN
# 2000-01-04                                NaN
# 2000-01-05                                NaN
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-01                                      NaN
# 2000-01-02                                      NaN
# 2000-01-03                                      NaN
# 2000-01-04                                      NaN
# 2000-01-05                                      NaN
#
#             trade_Trade Policy EMV Fraction
# 2000-01-01                              NaN
# 2000-01-02                              NaN
# 2000-01-03                              NaN
# 2000-01-04                              NaN
# 2000-01-05                              NaN
#
# [5 rows x 46 columns]

# %%
imp = KNNImputer(n_neighbors=5, weights="uniform")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-986852db39ed> in <module>
# ----> 1 imp = KNNImputer(n_neighbors=5, weights="uniform")
#
# NameError: name 'KNNImputer' is not defined

# %%
df_imputed = imp.fit_transform(df)

# %%
df_final = pd.DataFrame(data=df_imputed, index=df.index, columns=df.columns)

# %%
df_final.head()

# %%
df_final.to_csv(r'KNNImputed.csv', index = True)
