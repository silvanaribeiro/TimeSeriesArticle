# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.impute import KNNImputer

# %%
df = pd.read_csv('CompleteIndexes.csv', parse_dates=True, index_col=0)
df.head()
# Out:
#              sp500_Open   sp500_High    sp500_Low  sp500_Close  sp500_Volume  \
# 2000-01-01          NaN          NaN          NaN          NaN           NaN
# 2000-01-02          NaN          NaN          NaN          NaN           NaN
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  9.318000e+08
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1.009000e+09
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1.085500e+09
#
#              vix_Open  vix_High    vix_Low  vix_Close  vix_Volume  ...  \
# 2000-01-01        NaN       NaN        NaN        NaN         NaN  ...
# 2000-01-02        NaN       NaN        NaN        NaN         NaN  ...
# 2000-01-03  24.360001     26.15  23.980000  24.209999         0.0  ...
# 2000-01-04  24.940001     27.18  24.799999  27.010000         0.0  ...
# 2000-01-05  27.980000     29.00  25.850000  26.410000         0.0  ...
#
#              n100_High    n100_Low  n100_Close  n100_Volume  \
# 2000-01-01         NaN         NaN         NaN          NaN
# 2000-01-02         NaN         NaN         NaN          NaN
# 2000-01-03  996.770020  996.770020  996.770020          0.0
# 2000-01-04  955.969971  955.969971  955.969971          0.0
# 2000-01-05  930.260010  930.260010  930.260010          0.0
#
#             Overall EMV Tracker  infectious_daily_infect_emv_index        GPR  \
# 2000-01-01                  NaN                               1.05  40.634806
# 2000-01-02                  NaN                               2.62        NaN
# 2000-01-03                  NaN                               0.00        NaN
# 2000-01-04                  NaN                               0.99        NaN
# 2000-01-05                  NaN                               0.00        NaN
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-01                                NaN
# 2000-01-02                                NaN
# 2000-01-03                                NaN
# 2000-01-04                                NaN
# 2000-01-05                                NaN
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-01                                      NaN
# 2000-01-02                                      NaN
# 2000-01-03                                      NaN
# 2000-01-04                                      NaN
# 2000-01-05                                      NaN
#
#             trade_Trade Policy EMV Fraction
# 2000-01-01                              NaN
# 2000-01-02                              NaN
# 2000-01-03                              NaN
# 2000-01-04                              NaN
# 2000-01-05                              NaN
#
# [5 rows x 46 columns]

# %%
imp = KNNImputer(n_neighbors=5, weights="uniform")

# %%
df_imputed = imp.fit_transform(df)

# %%
df_final = pd.DataFrame(data=df_imputed, index=df.index, columns=df.columns)

# %%
df_final.head()
# Out:
#              sp500_Open   sp500_High    sp500_Low  sp500_Close  sp500_Volume  \
# 2000-01-01  1660.575977  1672.782007  1654.836011  1663.410010  3.649562e+09
# 2000-01-02  1601.676001  1611.643970  1593.976001  1602.157983  3.947684e+09
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  9.318000e+08
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1.009000e+09
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1.085500e+09
#
#              vix_Open  vix_High    vix_Low  vix_Close  vix_Volume  ...  \
# 2000-01-01  13.104000    13.508  12.764000  13.094000         0.0  ...
# 2000-01-02  17.770000    18.306  16.838000  17.482001         0.0  ...
# 2000-01-03  24.360001    26.150  23.980000  24.209999         0.0  ...
# 2000-01-04  24.940001    27.180  24.799999  27.010000         0.0  ...
# 2000-01-05  27.980000    29.000  25.850000  26.410000         0.0  ...
#
#              n100_High    n100_Low  n100_Close  n100_Volume  \
# 2000-01-01  755.503992  747.923999  753.057996  272019120.0
# 2000-01-02  704.655994  692.776013  695.566004  327640840.0
# 2000-01-03  996.770020  996.770020  996.770020          0.0
# 2000-01-04  955.969971  955.969971  955.969971          0.0
# 2000-01-05  930.260010  930.260010  930.260010          0.0
#
#             Overall EMV Tracker  infectious_daily_infect_emv_index        GPR  \
# 2000-01-01            19.184430                               1.05  40.634806
# 2000-01-02            19.184430                               2.62  59.066324
# 2000-01-03            29.827231                               0.00  75.555380
# 2000-01-04            17.123385                               0.99  53.844183
# 2000-01-05            23.945168                               0.00  99.104471
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-01                          33.530756
# 2000-01-02                          33.530756
# 2000-01-03                          86.380080
# 2000-01-04                          34.998316
# 2000-01-05                          65.130501
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-01                               200.571135
# 2000-01-02                               200.571135
# 2000-01-03                                70.426667
# 2000-01-04                               124.395303
# 2000-01-05                               129.586537
#
#             trade_Trade Policy EMV Fraction
# 2000-01-01                         0.014527
# 2000-01-02                         0.014527
# 2000-01-03                         0.022752
# 2000-01-04                         0.019407
# 2000-01-05                         0.021927
#
# [5 rows x 46 columns]

# %%
df_final.to_csv(r'KNNImputed.csv', index = True)
