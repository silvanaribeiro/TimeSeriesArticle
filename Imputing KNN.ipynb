# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.impute import KNNImputer
from sklearn import preprocessing
#INPUT = 'CompleteIndexes.csv'
#OUTPUT = 'KNNImputed.csv'
INPUT = 'CompleteWeeklyIndexes.csv'
OUTPUT = 'KNNWeeklyImputed.csv'

# %%
df = pd.read_csv(INPUT, parse_dates=True, index_col=0)
df = df.loc['2000-01-01':'2015-01-01'] #Selecting training data
df.head()
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume     dji_Close  \
# 2000-01-07  1441.469971  1.225200e+09  21.719999         0.0  11522.559570
# 2000-01-14  1465.150024  1.085900e+09  19.660000         0.0  11722.980469
# 2000-01-21  1441.359985  1.209800e+09  20.820000         0.0  11251.709961
# 2000-01-28  1360.160034  1.095800e+09  26.139999         0.0  10738.870117
# 2000-02-04  1424.369995  1.045100e+09  21.540001         0.0  10963.799805
#
#              dji_Volume    ndx_Close    ndx_Volume    n255_Close  n255_Volume  \
# 2000-01-07  184900000.0  3529.600098  1.634930e+09  18193.410156          0.0
# 2000-01-14  266830000.0  3704.739990  1.656630e+09  18956.550781          0.0
# 2000-01-21  205840000.0  3849.959961  1.923680e+09  18878.089844          0.0
# 2000-01-28  183090000.0  3446.129883  1.616370e+09  19434.779297          0.0
# 2000-02-04  166590000.0  3874.370117  1.751450e+09  19763.130859          0.0
#
#             ...     hsi_Close  hsi_Volume   n100_Close  n100_Volume  \
# 2000-01-07  ...  15405.629883         0.0   943.880005          0.0
# 2000-01-14  ...  15542.230469         0.0   973.859985          0.0
# 2000-01-21  ...  15108.410156         0.0   951.510010          0.0
# 2000-01-28  ...  16185.940430         0.0   948.210022          0.0
# 2000-02-04  ...           NaN         NaN  1010.429993          0.0
#
#             Overall EMV Tracker  infectious_daily_infect_emv_index  GPR  \
# 2000-01-07                  NaN                               0.00  NaN
# 2000-01-14                  NaN                               0.00  NaN
# 2000-01-21                  NaN                               0.00  NaN
# 2000-01-28            24.412899                               0.00  NaN
# 2000-02-04                  NaN                               0.75  NaN
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-07                                NaN
# 2000-01-14                                NaN
# 2000-01-21                                NaN
# 2000-01-28                          71.914247
# 2000-02-04                                NaN
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-07                                      NaN
# 2000-01-14                                      NaN
# 2000-01-21                                      NaN
# 2000-01-28                               117.577146
# 2000-02-04                                      NaN
#
#             trade_Trade Policy EMV Fraction
# 2000-01-07                              NaN
# 2000-01-14                              NaN
# 2000-01-21                              NaN
# 2000-01-28                         0.033573
# 2000-02-04                              NaN
#
# [5 rows x 22 columns]

# %%
#Scaled data has zero mean and unit variance
scaler = preprocessing.StandardScaler()
scaler.fit(df)
array = scaler.transform(df)
df_scaled = pd.DataFrame(data=array, index=df.index, columns=df.columns)
df_scaled.head()
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume  dji_Close  \
# 2000-01-07     0.588334     -1.002211   0.099912         0.0   0.020227
# 2000-01-14     0.676196     -1.085193  -0.125931         0.0   0.109104
# 2000-01-21     0.587926     -1.011385   0.001243         0.0  -0.099881
# 2000-01-28     0.286643     -1.079295   0.584489         0.0  -0.327300
# 2000-02-04     0.524886     -1.109498   0.080178         0.0  -0.227555
#
#             dji_Volume  ndx_Close  ndx_Volume  n255_Close  n255_Volume  ...  \
# 2000-01-07   -0.443957   1.707031   -0.537214    1.945019    -1.565826  ...
# 2000-01-14    0.336040   1.914791   -0.494165    2.196016    -1.565826  ...
# 2000-01-21   -0.244602   2.087059    0.035615    2.170210    -1.565826  ...
# 2000-01-28   -0.461189   1.608014   -0.574034    2.353305    -1.565826  ...
# 2000-02-04   -0.618274   2.116016   -0.306059    2.461300    -1.565826  ...
#
#             hsi_Close  hsi_Volume  n100_Close  n100_Volume  \
# 2000-01-07  -0.455167   -1.135995    1.241361    -1.046107
# 2000-01-14  -0.427369   -1.135995    1.432190    -1.046107
# 2000-01-21  -0.515651   -1.135995    1.289928    -1.046107
# 2000-01-28  -0.296374   -1.135995    1.268922    -1.046107
# 2000-02-04        NaN         NaN    1.664966    -1.046107
#
#             Overall EMV Tracker  infectious_daily_infect_emv_index  GPR  \
# 2000-01-07                  NaN                          -0.472653  NaN
# 2000-01-14                  NaN                          -0.472653  NaN
# 2000-01-21                  NaN                          -0.472653  NaN
# 2000-01-28             0.239136                          -0.472653  NaN
# 2000-02-04                  NaN                           0.309479  NaN
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-07                                NaN
# 2000-01-14                                NaN
# 2000-01-21                                NaN
# 2000-01-28                          -0.038733
# 2000-02-04                                NaN
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-07                                      NaN
# 2000-01-14                                      NaN
# 2000-01-21                                      NaN
# 2000-01-28                                 0.104335
# 2000-02-04                                      NaN
#
#             trade_Trade Policy EMV Fraction
# 2000-01-07                              NaN
# 2000-01-14                              NaN
# 2000-01-21                              NaN
# 2000-01-28                         1.056953
# 2000-02-04                              NaN
#
# [5 rows x 22 columns]

# %%
imp = KNNImputer(n_neighbors=5, weights="uniform")

# %%
df_imputed = imp.fit_transform(df_scaled)

# %%
df_final = pd.DataFrame(data=df_imputed, index=df.index, columns=df.columns)

# %%
df_final.tail()
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume  dji_Close  \
# 2014-11-28     2.911367     -0.240038  -0.819907         0.0   2.816486
# 2014-12-05     2.940345      0.305022  -0.977778         0.0   2.874378
# 2014-12-12     2.669338      0.744673   0.029747         0.0   2.573736
# 2014-12-19     2.922831      2.119495  -0.473467         0.0   2.806092
# 2014-12-26     2.990064     -0.698382  -0.691636         0.0   2.916471
#
#             dji_Volume  ndx_Close  ndx_Volume  n255_Close  n255_Volume  ...  \
# 2014-11-28   -1.438162   2.665750   -1.799580    1.703751     0.483228  ...
# 2014-12-05   -1.451109   2.634646   -0.275012    1.855242     0.205623  ...
# 2014-12-12   -1.043260   2.501441   -0.033442    1.674719     1.382009  ...
# 2014-12-19    1.067770   2.599307    2.742025    1.756885     0.850162  ...
# 2014-12-26   -1.703778   2.637635   -1.935233    1.821862    -0.377072  ...
#
#             hsi_Close  hsi_Volume  n100_Close  n100_Volume  \
# 2014-11-28   1.291229    1.966740    0.647232     1.115397
# 2014-12-05   1.294320    3.806885    0.708656     1.525285
# 2014-12-12   1.140995    0.477969    0.360097     1.413037
# 2014-12-19   1.114018    1.135032    0.528775     3.645977
# 2014-12-26   1.298251    0.552799    0.515408     0.226231
#
#             Overall EMV Tracker  infectious_daily_infect_emv_index       GPR  \
# 2014-11-28            -1.028382                          -0.472653  0.224111
# 2014-12-05            -0.417633                          -0.472653  0.085526
# 2014-12-12            -0.926569                           0.017483  0.224111
# 2014-12-19            -0.704534                           0.507619  0.342817
# 2014-12-26            -0.481866                           2.186597  0.187499
#
#             trade_US Trade Policy Uncertainty  \
# 2014-11-28                          -1.161981
# 2014-12-05                           0.502217
# 2014-12-12                           0.567321
# 2014-12-19                           0.432828
# 2014-12-26                           0.332941
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2014-11-28                                -0.616267
# 2014-12-05                                -0.276995
# 2014-12-12                                 0.306237
# 2014-12-19                                -0.028040
# 2014-12-26                                -0.400199
#
#             trade_Trade Policy EMV Fraction
# 2014-11-28                        -0.748109
# 2014-12-05                        -0.496527
# 2014-12-12                        -0.869256
# 2014-12-19                        -0.790725
# 2014-12-26                        -0.480409
#
# [5 rows x 22 columns]

# %%
array_2 = scaler.inverse_transform(df_final)
df_final2 = pd.DataFrame(data=array_2, index=df.index, columns=df.columns)
df_final2.head()
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume     dji_Close  \
# 2000-01-07  1441.469971  1.225200e+09  21.719999         0.0  11522.559570
# 2000-01-14  1465.150024  1.085900e+09  19.660000         0.0  11722.980469
# 2000-01-21  1441.359985  1.209800e+09  20.820000         0.0  11251.709961
# 2000-01-28  1360.160034  1.095800e+09  26.139999         0.0  10738.870117
# 2000-02-04  1424.369995  1.045100e+09  21.540001         0.0  10963.799805
#
#              dji_Volume    ndx_Close    ndx_Volume    n255_Close  n255_Volume  \
# 2000-01-07  184900000.0  3529.600098  1.634930e+09  18193.410156          0.0
# 2000-01-14  266830000.0  3704.739990  1.656630e+09  18956.550781          0.0
# 2000-01-21  205840000.0  3849.959961  1.923680e+09  18878.089844          0.0
# 2000-01-28  183090000.0  3446.129883  1.616370e+09  19434.779297          0.0
# 2000-02-04  166590000.0  3874.370117  1.751450e+09  19763.130859          0.0
#
#             ...     hsi_Close  hsi_Volume   n100_Close   n100_Volume  \
# 2000-01-07  ...  15405.629883         0.0   943.880005  2.980232e-08
# 2000-01-14  ...  15542.230469         0.0   973.859985  2.980232e-08
# 2000-01-21  ...  15108.410156         0.0   951.510010  2.980232e-08
# 2000-01-28  ...  16185.940430         0.0   948.210022  2.980232e-08
# 2000-02-04  ...  16508.498242         0.0  1010.429993  2.980232e-08
#
#             Overall EMV Tracker  infectious_daily_infect_emv_index        GPR  \
# 2000-01-07            26.228083                               0.00  67.608411
# 2000-01-14            26.581681                               0.00  55.703358
# 2000-01-21            24.398514                               0.00  67.608411
# 2000-01-28            24.412899                               0.00  67.608411
# 2000-02-04            26.421125                               0.75  56.185971
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-07                          78.920857
# 2000-01-14                          59.817220
# 2000-01-21                          58.920494
# 2000-01-28                          71.914247
# 2000-02-04                          58.794812
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-07                                80.800261
# 2000-01-14                                66.518457
# 2000-01-21                                71.545688
# 2000-01-28                               117.577146
# 2000-02-04                                75.979000
#
#             trade_Trade Policy EMV Fraction
# 2000-01-07                         0.029950
# 2000-01-14                         0.030678
# 2000-01-21                         0.032724
# 2000-01-28                         0.033573
# 2000-02-04                         0.027932
#
# [5 rows x 22 columns]

# %%
df_final2.to_csv(OUTPUT, index = True)
