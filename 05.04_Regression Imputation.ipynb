# %% [markdown]
# ## This notebook inputs the missing values using Regression

# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn import preprocessing
INPUT = 'CompleteIndexes.csv'
OUTPUT = 'RegressionImputed.csv'
#INPUT = 'CompleteWeeklyIndexes.csv'
#OUTPUT = 'RegressionWeeklyImputed.csv'

# %% [markdown]
# #### Choose wether the imputation should be done on the data set with daily or weekly granularity

# %%
INPUT, OUTPUT = 'CompleteIndexes.csv','RegressionImputed.csv'
#INPUT, OUTPUT = 'CompleteWeeklyIndexes.csv', 'RegressionWeeklyImputed.csv'

# %%
df = pd.read_csv(INPUT, parse_dates=True, index_col=0)
df = df.loc['2000-01-01':'2015-01-01'] #Selecting training data
df.head()
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume     dji_Close  \
# 2000-01-01          NaN           NaN        NaN         NaN           NaN
# 2000-01-02          NaN           NaN        NaN         NaN           NaN
# 2000-01-03  1455.219971  9.318000e+08  24.209999         0.0  11357.509766
# 2000-01-04  1399.420044  1.009000e+09  27.010000         0.0  10997.929688
# 2000-01-05  1402.109985  1.085500e+09  26.410000         0.0  11122.650391
#
#              dji_Volume    ndx_Close    ndx_Volume    n255_Close  n255_Volume  \
# 2000-01-01          NaN          NaN           NaN           NaN          NaN
# 2000-01-02          NaN          NaN           NaN           NaN          NaN
# 2000-01-03  169750000.0  3790.550049  1.510070e+09           NaN          NaN
# 2000-01-04  178420000.0  3546.199951  1.511840e+09  19002.859375          0.0
# 2000-01-05  203190000.0  3507.310059  1.735670e+09  18542.550781          0.0
#
#             ...     hsi_Close  hsi_Volume  n100_Close  n100_Volume  \
# 2000-01-01  ...           NaN         NaN         NaN          NaN
# 2000-01-02  ...           NaN         NaN         NaN          NaN
# 2000-01-03  ...  17369.630859         0.0  996.770020          0.0
# 2000-01-04  ...  17072.820313         0.0  955.969971          0.0
# 2000-01-05  ...  15846.719727         0.0  930.260010          0.0
#
#             Overall EMV Tracker  infectious_daily_infect_emv_index        GPR  \
# 2000-01-01                  NaN                               1.05  40.634806
# 2000-01-02                  NaN                               2.62        NaN
# 2000-01-03                  NaN                               0.00        NaN
# 2000-01-04                  NaN                               0.99        NaN
# 2000-01-05                  NaN                               0.00        NaN
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-01                                NaN
# 2000-01-02                                NaN
# 2000-01-03                                NaN
# 2000-01-04                                NaN
# 2000-01-05                                NaN
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-01                                      NaN
# 2000-01-02                                      NaN
# 2000-01-03                                      NaN
# 2000-01-04                                      NaN
# 2000-01-05                                      NaN
#
#             trade_Trade Policy EMV Fraction
# 2000-01-01                              NaN
# 2000-01-02                              NaN
# 2000-01-03                              NaN
# 2000-01-04                              NaN
# 2000-01-05                              NaN
#
# [5 rows x 22 columns]

# %%
#Scaled data has zero mean and unit variance
scaler = preprocessing.StandardScaler()
scaler.fit(df)
array = scaler.transform(df)
df_scaled = pd.DataFrame(data=array, index=df.index, columns=df.columns)
df_scaled.head()
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume  dji_Close  \
# 2000-01-01          NaN           NaN        NaN         NaN        NaN
# 2000-01-02          NaN           NaN        NaN         NaN        NaN
# 2000-01-03     0.641027     -1.224614   0.362660         0.0  -0.051956
# 2000-01-04     0.434069     -1.176913   0.673428         0.0  -0.211494
# 2000-01-05     0.444045     -1.129643   0.606834         0.0  -0.156158
#
#             dji_Volume  ndx_Close  ndx_Volume  n255_Close  n255_Volume  ...  \
# 2000-01-01         NaN        NaN         NaN         NaN          NaN  ...
# 2000-01-02         NaN        NaN         NaN         NaN          NaN  ...
# 2000-01-03   -0.499308   2.024667   -0.940188         NaN          NaN  ...
# 2000-01-04   -0.400411   1.733875   -0.935897    2.191749    -1.557786  ...
# 2000-01-05   -0.117863   1.687594   -0.393291    2.041177    -1.557786  ...
#
#             hsi_Close  hsi_Volume  n100_Close  n100_Volume  \
# 2000-01-01        NaN         NaN         NaN          NaN
# 2000-01-02        NaN         NaN         NaN          NaN
# 2000-01-03  -0.055288   -1.102314    1.590810    -1.066962
# 2000-01-04  -0.115682   -1.102314    1.330305    -1.066962
# 2000-01-05  -0.365162   -1.102314    1.166150    -1.066962
#
#             Overall EMV Tracker  infectious_daily_infect_emv_index       GPR  \
# 2000-01-01                  NaN                           0.429430 -0.711548
# 2000-01-02                  NaN                           1.800563       NaN
# 2000-01-03                  NaN                          -0.487570       NaN
# 2000-01-04                  NaN                           0.377030       NaN
# 2000-01-05                  NaN                          -0.487570       NaN
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-01                                NaN
# 2000-01-02                                NaN
# 2000-01-03                                NaN
# 2000-01-04                                NaN
# 2000-01-05                                NaN
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-01                                      NaN
# 2000-01-02                                      NaN
# 2000-01-03                                      NaN
# 2000-01-04                                      NaN
# 2000-01-05                                      NaN
#
#             trade_Trade Policy EMV Fraction
# 2000-01-01                              NaN
# 2000-01-02                              NaN
# 2000-01-03                              NaN
# 2000-01-04                              NaN
# 2000-01-05                              NaN
#
# [5 rows x 22 columns]

# %%
imp = IterativeImputer(max_iter=10, random_state=0)
imp.fit(df_scaled)

# %%
df_imputed = imp.transform(df_scaled)
df_final = pd.DataFrame(data=df_imputed, index=df.index, columns=df.columns)
df_final.head()

# %%
# Descaling the data
array_2 = scaler.inverse_transform(df_final)
df_final2 = pd.DataFrame(data=array_2, index=df.index, columns=df.columns)
df_final2.head()
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume     dji_Close  \
# 2000-01-01  1280.443519  3.113586e+09  20.328969         0.0  11337.410644
# 2000-01-02  1285.889631  2.929650e+09  21.718352         0.0  11477.093897
# 2000-01-03  1455.219971  9.318000e+08  24.209999         0.0  11357.509766
# 2000-01-04  1399.420044  1.009000e+09  27.010000         0.0  10997.929688
# 2000-01-05  1402.109985  1.085500e+09  26.410000         0.0  11122.650391
#
#               dji_Volume    ndx_Close    ndx_Volume    n255_Close  \
# 2000-01-01  2.170728e+08  2142.317496  1.921585e+09  12220.023233
# 2000-01-02  2.136590e+08  2093.942805  1.900607e+09  12277.036505
# 2000-01-03  1.697500e+08  3790.550049  1.510070e+09  16803.955434
# 2000-01-04  1.784200e+08  3546.199951  1.511840e+09  19002.859375
# 2000-01-05  2.031900e+08  3507.310059  1.735670e+09  18542.550781
#
#               n255_Volume  ...     hsi_Close    hsi_Volume  n100_Close  \
# 2000-01-01  105106.968699  ...  17999.440366  1.149377e+09  792.262703
# 2000-01-02  105264.313952  ...  17314.245617  1.127768e+09  740.349506
# 2000-01-03   -1486.168125  ...  17369.630859  0.000000e+00  996.770020
# 2000-01-04       0.000000  ...  17072.820313  0.000000e+00  955.969971
# 2000-01-05       0.000000  ...  15846.719727  0.000000e+00  930.260010
#
#              n100_Volume  Overall EMV Tracker  \
# 2000-01-01  1.591055e+08            20.499428
# 2000-01-02  1.782562e+08            22.674335
# 2000-01-03  0.000000e+00            24.018629
# 2000-01-04  0.000000e+00            26.899669
# 2000-01-05  0.000000e+00            26.825446
#
#             infectious_daily_infect_emv_index         GPR  \
# 2000-01-01                               1.05   40.634806
# 2000-01-02                               2.62   94.022770
# 2000-01-03                               0.00   71.282143
# 2000-01-04                               0.99  113.312964
# 2000-01-05                               0.00  105.559217
#
#             trade_US Trade Policy Uncertainty  \
# 2000-01-01                          53.792164
# 2000-01-02                          53.236450
# 2000-01-03                          65.258089
# 2000-01-04                          63.220009
# 2000-01-05                          64.392529
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-01                               102.241439
# 2000-01-02                                90.210852
# 2000-01-03                                88.312284
# 2000-01-04                                94.606481
# 2000-01-05                                98.440950
#
#             trade_Trade Policy EMV Fraction
# 2000-01-01                         0.021361
# 2000-01-02                         0.020939
# 2000-01-03                         0.027100
# 2000-01-04                         0.028208
# 2000-01-05                         0.027033
#
# [5 rows x 22 columns]

# %%
df_final2.to_csv(OUTPUT, index = True)
