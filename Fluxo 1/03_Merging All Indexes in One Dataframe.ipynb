# %% [markdown]
# ## This notebook merges all indexes using the dates as index and generates one file with daily granularity and one file with weekly granularity

# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
#Daily
v_sp500 = pd.read_csv('S&P500.csv', parse_dates=True)
v_sp500['Date'] = pd.to_datetime(v_sp500['Date'], infer_datetime_format=True)
v_sp500.index = v_sp500['Date'].values
v_sp500 = v_sp500.loc['2000-01-01':'2020-03-18']
v_sp500 = v_sp500.drop(['Date', 'Adj Close', 'High', 'Low', 'Open'], axis=1)
v_sp500 = v_sp500.add_prefix('sp500_')
v_sp500.tail()
# Out:
#             sp500_Close  sp500_Volume
# 2020-03-12  2480.639893    8829380000
# 2020-03-13  2711.020020    8258670000
# 2020-03-16  2386.129883    7781540000
# 2020-03-17  2529.189941    8358500000
# 2020-03-18  2398.100098    8755780000

# %%
#Daily
v_vix = pd.read_csv('VIX.csv', parse_dates=True)
v_vix['Date'] = pd.to_datetime(v_vix['Date'], infer_datetime_format=True)
v_vix.index = v_vix['Date'].values
v_vix = v_vix.loc['2000-01-01':'2020-03-18']
v_vix = v_vix.drop(['Date', 'Adj Close', 'High', 'Low', 'Open'], axis=1)
v_vix = v_vix.add_prefix('vix_')
v_vix.head()
# Out:
#             vix_Close  vix_Volume
# 2000-01-03  24.209999           0
# 2000-01-04  27.010000           0
# 2000-01-05  26.410000           0
# 2000-01-06  25.730000           0
# 2000-01-07  21.719999           0

# %%
#Daily
v_dji = pd.read_csv('^DJI.csv', parse_dates=True)
v_dji['Date'] = pd.to_datetime(v_dji['Date'], infer_datetime_format=True)
v_dji.index = v_dji['Date'].values
v_dji = v_dji.loc['2000-01-01':'2020-03-18']
v_dji = v_dji.drop(['Date', 'Adj Close', 'High', 'Low', 'Open', 'High', 'Low', 'Open'], axis=1)
v_dji = v_dji.add_prefix('dji_')
v_dji.head()
# Out:
#                dji_Close  dji_Volume
# 2000-01-03  11357.509766   169750000
# 2000-01-04  10997.929688   178420000
# 2000-01-05  11122.650391   203190000
# 2000-01-06  11253.259766   176550000
# 2000-01-07  11522.559570   184900000

# %%
#Daily
v_ndx = pd.read_csv('^NDX.csv', parse_dates=True)
v_ndx['Date'] = pd.to_datetime(v_ndx['Date'], infer_datetime_format=True)
v_ndx.index = v_ndx['Date'].values
v_ndx = v_ndx.loc['2000-01-01':'2020-03-18']
v_ndx = v_ndx.drop(['Date', 'Adj Close', 'High', 'Low', 'Open'], axis=1)
v_ndx = v_ndx.add_prefix('ndx_')
v_ndx.head()
# Out:
#               ndx_Close  ndx_Volume
# 2000-01-03  3790.550049  1510070000
# 2000-01-04  3546.199951  1511840000
# 2000-01-05  3507.310059  1735670000
# 2000-01-06  3340.810059  1598320000
# 2000-01-07  3529.600098  1634930000

# %%
#Daily
v_n225 = pd.read_csv('N225.csv', parse_dates=True)
v_n225['Date'] = pd.to_datetime(v_n225['Date'], infer_datetime_format=True)
v_n225.index = v_n225['Date'].values
v_n225 = v_n225.loc['2000-01-01':'2020-03-18']
v_n225 = v_n225.drop(['Date', 'Adj Close', 'High', 'Low', 'Open'], axis=1)
v_n225 = v_n225.add_prefix('n255_')
v_n225.head()
# Out:
#               n255_Close  n255_Volume
# 2000-01-04  19002.859375          0.0
# 2000-01-05  18542.550781          0.0
# 2000-01-06  18168.269531          0.0
# 2000-01-07  18193.410156          0.0
# 2000-01-10           NaN          NaN

# %%
#Daily
v_ftse = pd.read_csv('CompleteFTSE.csv', parse_dates=True)
v_ftse['Date'] = pd.to_datetime(v_ftse['Date'], infer_datetime_format=True)
v_ftse.index = v_ftse['Date'].values
v_ftse = v_ftse.loc['2000-01-01':'2020-03-18']
v_ftse = v_ftse.drop(['Date', 'Adj Close', 'High', 'Low', 'Open'], axis=1)
v_ftse = v_ftse.add_prefix('ftse_')
v_ftse.head()
# Out:
#              ftse_Close  ftse_Volume
# 2000-01-03          NaN          NaN
# 2000-01-04  6665.899902  633449000.0
# 2000-01-05  6535.899902  670234000.0
# 2000-01-06  6447.200195  785532000.0
# 2000-01-07  6504.799805  888306000.0

# %%
#Daily
v_hsi = pd.read_csv('^HSI.csv', parse_dates=True)
v_hsi['Date'] = pd.to_datetime(v_hsi['Date'], infer_datetime_format=True)
v_hsi.index = v_hsi['Date'].values
v_hsi = v_hsi.loc['2000-01-01':'2020-03-18']
v_hsi = v_hsi.drop(['Date', 'Adj Close', 'High', 'Low', 'Open'], axis=1)
v_hsi = v_hsi.add_prefix('hsi_')
v_hsi.head()
# Out:
#                hsi_Close  hsi_Volume
# 2000-01-03  17369.630859         0.0
# 2000-01-04  17072.820313         0.0
# 2000-01-05  15846.719727         0.0
# 2000-01-06  15153.230469         0.0
# 2000-01-07  15405.629883         0.0

# %%
#Daily
v_n100 = pd.read_csv('^N100.csv', parse_dates=True)
v_n100['Date'] = pd.to_datetime(v_n100['Date'], infer_datetime_format=True)
v_n100.index = v_n100['Date'].values
v_n100 = v_n100.loc['2000-01-01':'2020-03-18']
v_n100 = v_n100.drop(['Date', 'Adj Close', 'High', 'Low', 'Open'], axis=1)
v_n100 = v_n100.add_prefix('n100_')
v_n100.head()
# Out:
#             n100_Close  n100_Volume
# 2000-01-03  996.770020          0.0
# 2000-01-04  955.969971          0.0
# 2000-01-05  930.260010          0.0
# 2000-01-06  922.460022          0.0
# 2000-01-07  943.880005          0.0

# %%
#Monthly
v_emv =  pd.read_excel('EMV_Data.xlsx') 
Date = v_emv.apply(lambda x: datetime(int(x['Year']),int(x['Month']),28), axis=1)
v_emv['Date'] = Date
v_emv['Date'] = pd.to_datetime(v_emv['Date'], infer_datetime_format=True)
v_emv.index = v_emv['Date'].values
v_emv = v_emv.loc['2000-01-01':'2020-03-18']
v_emv = v_emv[['Overall EMV Tracker']]
v_emv.head()
# Out:
#             Overall EMV Tracker
# 2000-01-28            24.412899
# 2000-02-28            19.913437
# 2000-03-28            26.104673
# 2000-04-28            43.429073
# 2000-05-28            34.308361

# %%
#Daily
v_infectious = pd.read_csv('All_Infectious_EMV_Data.csv')
Date = v_infectious.apply(lambda x: datetime(int(x['year']),int(x['month']), int(x['day'])), axis=1)
v_infectious['Date'] = Date
v_infectious['Date'] = pd.to_datetime(v_infectious['Date'], infer_datetime_format=True)
v_infectious.index = v_infectious['Date'].values
v_infectious = v_infectious.loc['2000-01-01':'2020-03-18']
v_infectious = v_infectious.drop(['Date', 'day', 'month', 'year'], axis=1)
v_infectious = v_infectious.add_prefix('infectious_')
v_infectious.head()
# Out:
#             infectious_daily_infect_emv_index
# 2000-01-01                               1.05
# 2000-01-02                               2.62
# 2000-01-03                               0.00
# 2000-01-04                               0.99
# 2000-01-05                               0.00

# %%
#Quarterly - might not use
v_financial_stress = pd.read_excel('Financial_Stress.xlsx')
Date = v_financial_stress.apply(lambda x: datetime(int(x['year']),int(x['quarter'])*3, 28), axis=1)
v_financial_stress['Date'] = Date
v_financial_stress['Date'] = pd.to_datetime(v_financial_stress['Date'], infer_datetime_format=True)
v_financial_stress.index = v_financial_stress['Date'].values
v_financial_stress = v_financial_stress.loc['2000-01-01':'2020-03-18']
v_financial_stress = v_financial_stress.drop(['date', 'Date', 'quarter', 'year'], axis=1)
v_financial_stress = v_financial_stress.add_prefix('financial_')
v_financial_stress.head()
# Out:
#             financial_indicator
# 2000-03-28           101.588292
# 2000-06-28           101.361929
# 2000-09-28           100.836200
# 2000-12-28           101.377272
# 2001-03-28           102.227537

# %%
#Monthly
v_gpr = pd.read_excel('gpr_web_latest.xlsx')
v_gpr['Date'] = pd.to_datetime(v_gpr['Date'], infer_datetime_format=True)
v_gpr.index = v_gpr['Date'].values
v_gpr = v_gpr.loc['2000-01-01':'2020-03-18']
v_gpr = v_gpr[['GPR']]
v_gpr.head()
# Out:
#                   GPR
# 2000-01-01  40.634806
# 2000-02-01  34.391162
# 2000-03-01  54.098793
# 2000-04-01  35.769024
# 2000-05-01  34.094887

# %%
#Monthly
v_trade_uncertainty = pd.read_excel('Trade_Uncertainty_Data.xlsx') 
Date = v_trade_uncertainty.apply(lambda x: datetime(int(x['Year']),int(x['Month']),28), axis=1)
v_trade_uncertainty['Date'] = Date
v_trade_uncertainty['Date'] = pd.to_datetime(v_trade_uncertainty['Date'], infer_datetime_format=True)
v_trade_uncertainty.index = v_trade_uncertainty['Date'].values
v_trade_uncertainty = v_trade_uncertainty.loc['2000-01-01':'2020-03-18']
v_trade_uncertainty = v_trade_uncertainty.drop(['Date', 'Year', 'Month'], axis=1)
v_trade_uncertainty = v_trade_uncertainty.add_prefix('trade_')
v_trade_uncertainty.head()
# Out:
#             trade_US Trade Policy Uncertainty  \
# 2000-01-28                          71.914247
# 2000-02-28                          50.352413
# 2000-03-28                          88.179754
# 2000-04-28                          82.574216
# 2000-05-28                         245.009584
#
#             trade_Japanese Trade Policy Uncertainty  \
# 2000-01-28                               117.577146
# 2000-02-28                                58.499365
# 2000-03-28                                31.808480
# 2000-04-28                                54.061788
# 2000-05-28                                73.961645
#
#             trade_Trade Policy EMV Fraction
# 2000-01-28                         0.033573
# 2000-02-28                         0.026471
# 2000-03-28                         0.028139
# 2000-04-28                         0.033755
# 2000-05-28                         0.025000

# %%
df = pd.concat([v_sp500, v_vix, v_dji, v_ndx, v_n225, v_ftse, v_hsi, v_n100, v_emv, v_infectious, v_gpr, v_trade_uncertainty], axis=1, join='outer')

# %%
at_least_one_value_missing = df.apply(lambda x: (len(x)-x.count())>=1, axis=1)

# %%
at_least_one_value_missing.value_counts()
# Out:
# True    7383
# dtype: int64

# %%
df
# Out:
#             sp500_Close  sp500_Volume  vix_Close  vix_Volume     dji_Close  \
# 2000-01-01          NaN           NaN        NaN         NaN           NaN
# 2000-01-02          NaN           NaN        NaN         NaN           NaN
# 2000-01-03  1455.219971  9.318000e+08  24.209999         0.0  11357.509766
# 2000-01-04  1399.420044  1.009000e+09  27.010000         0.0  10997.929688
# 2000-01-05  1402.109985  1.085500e+09  26.410000         0.0  11122.650391
# 2000-01-06  1403.449951  1.092300e+09  25.730000         0.0  11253.259766
# 2000-01-07  1441.469971  1.225200e+09  21.719999         0.0  11522.559570
# 2000-01-08          NaN           NaN        NaN         NaN           NaN
# 2000-01-09          NaN           NaN        NaN         NaN           NaN
# 2000-01-10  1457.599976  1.064800e+09  21.709999         0.0  11572.200195
# 2000-01-11  1438.560059  1.014000e+09  22.500000         0.0  11511.080078
# 2000-01-12  1432.250000  9.746000e+08  22.840000         0.0  11551.099609
# 2000-01-13  1449.680054  1.030400e+09  21.709999         0.0  11582.429688
# 2000-01-14  1465.150024  1.085900e+09  19.660000         0.0  11722.980469
# 2000-01-15          NaN           NaN        NaN         NaN           NaN
# 2000-01-16          NaN           NaN        NaN         NaN           NaN
# 2000-01-17          NaN           NaN        NaN         NaN           NaN
# 2000-01-18  1455.140015  1.056700e+09  21.500000         0.0  11560.719727
# 2000-01-19  1455.900024  1.087800e+09  21.719999         0.0  11489.360352
# 2000-01-20  1445.569946  1.100700e+09  21.750000         0.0  11351.299805
# 2000-01-21  1441.359985  1.209800e+09  20.820000         0.0  11251.709961
# 2000-01-22          NaN           NaN        NaN         NaN           NaN
# 2000-01-23          NaN           NaN        NaN         NaN           NaN
# 2000-01-24  1401.530029  1.115800e+09  24.070000         0.0  11008.169922
# 2000-01-25  1410.030029  1.073700e+09  23.020000         0.0  11029.889648
# 2000-01-26  1404.089966  1.117300e+09  23.030001         0.0  11032.990234
# 2000-01-27  1398.560059  1.129500e+09  23.540001         0.0  11028.019531
# 2000-01-28  1360.160034  1.095800e+09  26.139999         0.0  10738.870117
# 2000-01-29          NaN           NaN        NaN         NaN           NaN
# 2000-01-30          NaN           NaN        NaN         NaN           NaN
# ...                 ...           ...        ...         ...           ...
# 2020-02-18  3370.290039  3.746720e+09  14.830000         0.0  29232.189453
# 2020-02-19  3386.149902  3.600150e+09  14.380000         0.0  29348.029297
# 2020-02-20  3373.229980  4.007320e+09  15.560000         0.0  29219.980469
# 2020-02-21  3337.750000  3.899270e+09  17.080000         0.0  28992.410156
# 2020-03-16  770130000.0  7020.379883  4.594360e+09  17002.039063     158100.0
# 2020-03-17  793060000.0  7473.950195  4.900000e+09  17011.529297     198800.0
# 2020-03-18  871360000.0  7175.180176  4.890820e+09  16726.550781     177200.0
#
#             ...     hsi_Close    hsi_Volume   n100_Close  n100_Volume  \
# 2000-01-01  ...           NaN           NaN          NaN          NaN
# 2000-01-02  ...           NaN           NaN          NaN          NaN
# 2000-01-03  ...  17369.630859  0.000000e+00   996.770020          0.0
# 2000-01-04  ...  17072.820313  0.000000e+00   955.969971          0.0
# 2000-01-05  ...  15846.719727  0.000000e+00   930.260010          0.0
# 2000-01-06  ...  15153.230469  0.000000e+00   922.460022          0.0
# 2000-01-07  ...  15405.629883  0.000000e+00   943.880005          0.0
# 2000-01-08  ...           NaN           NaN          NaN          NaN
# 2000-01-09  ...           NaN           NaN          NaN          NaN
# 2000-01-10  ...  15848.150391  0.000000e+00   960.219971          0.0
# 2000-01-11  ...  15862.099609  0.000000e+00   954.059998          0.0
# 2000-01-12  ...  15714.200195  0.000000e+00   946.830017          0.0
# 2000-01-13  ...  15633.959961  0.000000e+00   951.820007          0.0
# 2000-01-14  ...  15542.230469  0.000000e+00   973.859985          0.0
# 2000-01-15  ...           NaN           NaN          NaN          NaN
# 2000-01-16  ...           NaN           NaN          NaN          NaN
# 2000-01-17  ...  15574.559570  0.000000e+00   979.960022          0.0
# 2000-01-18  ...  15789.200195  0.000000e+00   952.590027          0.0
# 2000-01-19  ...  15275.339844  0.000000e+00   951.260010          0.0
# 2000-01-20  ...  15215.309570  0.000000e+00   955.409973          0.0
# 2000-01-21  ...  15108.410156  0.000000e+00   951.510010          0.0
# 2000-01-22  ...           NaN           NaN          NaN          NaN
# 2000-01-23  ...           NaN           NaN          NaN          NaN
# 2000-01-24  ...  15167.549805  0.000000e+00   956.609985          0.0
# 2000-01-25  ...  15103.040039  0.000000e+00   943.880005          0.0
# 2000-01-26  ...  15427.719727  0.000000e+00   946.200012          0.0
# 2000-01-27  ...  15917.809570  0.000000e+00   948.150024          0.0
# 2000-01-28  ...  16185.940430  0.000000e+00   948.210022          0.0
# 2000-01-29  ...           NaN           NaN          NaN          NaN
# 2000-01-30  ...           NaN           NaN          NaN          NaN
# ...         ...           ...           ...          ...          ...
# 2020-02-18  ...  27530.199219  1.592221e+09  1172.729980  216363200.0
# 2020-02-19  ...  27655.810547  1.471538e+09  1182.099976  215731000.0
# 2020-02-20  ...  27609.160156  1.582073e+09  1171.089966  229248800.0
# 2020-02-21  ...  27308.810547  1.773613e+09  1164.170044  238290800.0
# 2020-02-22  ...           NaN           NaN          NaN          NaN
# 2020-02-23  ...           NaN           NaN          NaN          NaN
# 2020-02-24  ...  26820.880859  2.044657e+09  1120.449951  379225400.0
# 2020-02-25  ...  26893.230469  1.924043e+09  1099.270020  335196000.0
# 2020-02-26  ...  26696.490234  0.000000e+00  1099.410034  392984900.0
# 2020-02-27  ...  26778.619141  2.110370e+09  1059.359985  482892200.0
# 2000-01-01                                      NaN
# 2000-01-02                                      NaN
# 2000-01-03                                      NaN
# 2000-01-04                                      NaN
# 2000-01-05                                      NaN
# 2000-01-06                                      NaN
# 2000-01-07                                      NaN
# 2000-01-08                                      NaN
# 2000-01-09                                      NaN
# 2000-01-10                                      NaN
# 2000-01-11                                      NaN
# 2000-01-12                                      NaN
# 2000-01-13                                      NaN
# 2000-01-14                                      NaN
# 2000-01-15                                      NaN
# 2000-01-16                                      NaN
# 2000-01-17                                      NaN
# 2000-01-18                                      NaN
# 2000-01-19                                      NaN
# 2000-01-20                                      NaN
# 2000-01-21                                      NaN
# 2000-01-22                                      NaN
# 2000-01-23                                      NaN
# 2000-01-24                                      NaN
# 2000-01-25                                      NaN
# 2000-01-26                                      NaN
# 2000-01-27                                      NaN
# 2000-01-28                               117.577146
# 2000-01-29                                      NaN
# 2000-01-30                                      NaN
# ...                                             ...
# 2020-02-18                                      NaN
# 2020-02-19                                      NaN
# 2020-02-20                                      NaN
# 2020-02-21                                      NaN
# 2020-02-22                                      NaN
# 2020-02-23                                      NaN
# 2020-02-24                                      NaN
# 2020-02-25                                      NaN
# 2020-02-26                                      NaN
# 2020-02-27                                      NaN
# 2020-02-28                                      NaN
# 2020-02-29                                      NaN
# 2020-03-01                                      NaN
# 2020-03-02                                      NaN
# 2020-03-03                                      NaN
# 2020-03-04                                      NaN
# 2020-03-05                                      NaN
# 2020-03-06                                      NaN
# 2020-03-07                                      NaN
# 2020-03-08                                      NaN
# 2020-03-09                                      NaN
# 2020-03-10                                      NaN
# 2020-03-11                                      NaN
# 2020-03-12                                      NaN
# 2020-03-13                                      NaN
# 2020-03-14                                      NaN
# 2020-03-15                                      NaN
# 2020-03-16                                      NaN
# 2020-03-17                                      NaN
# 2020-03-18                                      NaN
#
#             trade_Trade Policy EMV Fraction
# 2000-01-01                              NaN
# 2000-01-02                              NaN
# 2000-01-03                              NaN
# 2000-01-04                              NaN
# 2000-01-05                              NaN
# 2000-01-06                              NaN
# 2000-01-07                              NaN
# 2000-01-08                              NaN
# 2000-01-09                              NaN
# 2000-01-10                              NaN
# 2000-01-11                              NaN
# 2000-01-12                              NaN
# 2000-01-13                              NaN
# 2000-01-14                              NaN
# 2000-01-15                              NaN
# 2000-01-16                              NaN
# 2000-01-17                              NaN
# 2000-01-18                              NaN
# 2000-01-19                              NaN
# 2000-01-20                              NaN
# 2000-01-21                              NaN
# 2000-01-22                              NaN
# 2000-01-23                              NaN
# 2000-01-24                              NaN
# 2000-01-25                              NaN
# 2000-01-26                              NaN
# 2000-01-27                              NaN
# 2000-01-28                         0.033573
# 2000-01-29                              NaN
# 2000-01-30                              NaN
# ...                                     ...
# 2020-02-18                              NaN
# 2020-02-19                              NaN
# 2020-02-20                              NaN
# 2020-02-21                              NaN
# 2020-02-22                              NaN
# 2020-02-23                              NaN
# 2020-02-24                              NaN
# 2020-02-25                              NaN
# 2020-02-26                              NaN
# 2020-02-27                              NaN
# 2020-02-28                              NaN
# 2020-02-29                              NaN
# 2020-03-01                              NaN
# 2020-03-02                              NaN
# 2020-03-03                              NaN
# 2020-03-04                              NaN
# 2020-03-05                              NaN
# 2020-03-06                              NaN
# 2020-03-07                              NaN
# 2020-03-08                              NaN
# 2020-03-09                              NaN
# 2020-03-10                              NaN
# 2020-03-11                              NaN
# 2020-03-12                              NaN
# 2020-03-13                              NaN
# 2020-03-14                              NaN
# 2020-03-15                              NaN
# 2020-03-16                              NaN
# 2020-03-17                              NaN
# 2020-03-18                              NaN
#
# [7383 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7383 entries, 2000-01-01 to 2020-03-18
# Data columns (total 22 columns):
# sp500_Close                                5084 non-null float64
# sp500_Volume                               5084 non-null float64
# vix_Close                                  5084 non-null float64
# vix_Volume                                 5084 non-null float64
# dji_Close                                  5084 non-null float64
# dji_Volume                                 5084 non-null float64
# ndx_Close                                  5084 non-null float64
# ndx_Volume                                 5084 non-null float64
# n255_Close                                 4952 non-null float64
# n255_Volume                                4952 non-null float64
# ftse_Close                                 4869 non-null float64
# ftse_Volume                                4869 non-null float64
# hsi_Close                                  4977 non-null float64
# hsi_Volume                                 4977 non-null float64
# n100_Close                                 5166 non-null float64
# n100_Volume                                5166 non-null float64
# Overall EMV Tracker                        242 non-null float64
# infectious_daily_infect_emv_index          7383 non-null float64
# GPR                                        243 non-null float64
# trade_US Trade Policy Uncertainty          235 non-null float64
# trade_Japanese Trade Policy Uncertainty    235 non-null float64
# trade_Trade Policy EMV Fraction            235 non-null float64
# dtypes: float64(22)
# memory usage: 1.3 MB

# %%
df.to_csv(r'CompleteIndexes.csv', index = True)

# %%
# Generating weekly sampled dataset
df_friday = datetime(2000,1,7)

df_weekly = pd.DataFrame(columns = df.columns)
df_out_weekly = pd.DataFrame(columns = df.columns)


while df_friday <= df.tail(1).index:
    df_weekly = df_weekly.append(df.loc[df_friday])
    df_friday+=timedelta(days=7)

# %%
df_weekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1054 entries, 2000-01-07 to 2020-03-13
# Data columns (total 22 columns):
# sp500_Close                                1021 non-null float64
# sp500_Volume                               1021 non-null float64
# vix_Close                                  1021 non-null float64
# vix_Volume                                 1021 non-null float64
# dji_Close                                  1021 non-null float64
# dji_Volume                                 1021 non-null float64
# ndx_Close                                  1021 non-null float64
# ndx_Volume                                 1021 non-null float64
# n255_Close                                 1009 non-null float64
# n255_Volume                                1009 non-null float64
# ftse_Close                                 978 non-null float64
# ftse_Volume                                978 non-null float64
# hsi_Close                                  993 non-null float64
# hsi_Volume                                 993 non-null float64
# n100_Close                                 1024 non-null float64
# n100_Volume                                1024 non-null float64
# Overall EMV Tracker                        36 non-null float64
# infectious_daily_infect_emv_index          1054 non-null float64
# GPR                                        35 non-null float64
# trade_US Trade Policy Uncertainty          35 non-null float64
# trade_Japanese Trade Policy Uncertainty    35 non-null float64
# trade_Trade Policy EMV Fraction            35 non-null float64
# dtypes: float64(22)
# memory usage: 189.4 KB

# %%
df_weekly.to_csv(r'CompleteWeeklyIndexes.csv', index = True)
